# %% [markdown]
# **Lista dos FIIs**
# * https://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-de-investimentos/fii/fiis-listados/
# * O arquivo csv chama-se "fiis-listados".
#
# ---
# **Lista dos FIAGROs**
# * https://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-de-investimentos/fiagro/fiagros-listados/
# * O arquivo csv chama-se "fiagros-listados".
#
# ---
# **Lista dos Fundos de Investimento em Participações (FIP)**
# * https://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-de-investimento-em-participacoes-fip.htm
# * O arquivo csv chama-se "fips-listados".
#
# ---
# **Lista dos Fundos Setoriais**
# * https://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-setoriais.htm
# * O arquivo csv chama-se "fiset-listados".
#
# ---
# **Lista dos FI-Infra**
# * https://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-de-investimentos/fi-infra/fi-infra-listados/
# * O arquivo csv chama-se "fi-infra-listados".
